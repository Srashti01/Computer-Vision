# %% [markdown]
# # single face detection

# %% [raw]
# This script loads an image and uses OpenCV’s Haar cascade classifiers to detect faces and eyes.
# It converts the image to grayscale for better detection, draws rectangles around faces and circles around eyes,
# and then displays the annotated result using Matplotlib. It demonstrates basic object detection on a static
# image rather than live video.

# %%
import cv2
import matplotlib.pyplot as plt

# Load cascades
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier("haarcascade_eye.xml")

# Load image
img = cv2.imread("singlegirl.jpg")

if img is None:
    print(" Image not found")
    exit()

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

for (x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0), 2)

    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

    eyes = eye_cascade.detectMultiScale(roi_gray, 1.1, 4)

    for (ex, ey, ew, eh) in eyes:
        center = (ex + ew//2, ey + eh//2)
        radius = ew//2
        cv2.circle(roi_color, center, radius, (0,255,0), 2)

# Convert BGR → RGB for matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,8))
plt.imshow(img_rgb)
plt.axis("off")
plt.title("Haar Face & Eye Detection")
plt.show()

# %% [markdown]
# # Face detection in a group photo

# %% [raw]
# This program loads a group photo and uses Haar cascade classifiers to detect multiple faces and eyes in the image.
# It converts the image to grayscale for efficient detection, draws rectangles around faces and circles around eyes,
# and displays the annotated result using Matplotlib.
# It demonstrates face and eye detection on a multi-person image.

# %%
import cv2
import matplotlib.pyplot as plt

# Load cascades
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier("haarcascade_eye.xml")

# Load image
img = cv2.imread("groupphoto.jpg")

if img is None:
    print(" Image not found")
    exit()

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

for (x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0), 2)

    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

    eyes = eye_cascade.detectMultiScale(roi_gray, 1.1, 4)

    for (ex, ey, ew, eh) in eyes:
        center = (ex + ew//2, ey + eh//2)
        radius = ew//2
        cv2.circle(roi_color, center, radius, (0,255,0), 2)

# Convert BGR → RGB for matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,8))
plt.imshow(img_rgb)
plt.axis("off")
plt.title("Haar Face & Eye Detection")
plt.show()

# %% [markdown]
# # For rotated face

# %%
This script loads a side-face image and applies Haar cascade classifiers to detect faces and eyes. 
The image is converted to grayscale to improve detection accuracy. 
However H model was trained mainly on front-facing faces (looking straight at the camera).

When the face is turned sideways:
One eye may be hidden
Nose and mouth shapes change
Facial symmetry is lost
Important features disappear
So the detector cannot recognize it as a face.

# %%
import cv2
import matplotlib.pyplot as plt

# Load cascades
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier("haarcascade_eye.xml")

# Load image
img = cv2.imread("sideface.jpg")

if img is None:
    print(" Image not found")
    exit()

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

for (x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0), 2)

    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

    eyes = eye_cascade.detectMultiScale(roi_gray, 1.1, 4)

    for (ex, ey, ew, eh) in eyes:
        center = (ex + ew//2, ey + eh//2)
        radius = ew//2
        cv2.circle(roi_color, center, radius, (0,255,0), 2)

# Convert BGR → RGB for matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,8))
plt.imshow(img_rgb)
plt.axis("off")
plt.title("Haar Face & Eye Detection")
plt.show()
